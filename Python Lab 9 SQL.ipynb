# %%
import pandas as pd
import sqlalchemy as alch

# %%
from getpass import getpass
password = getpass("Introduce your sql password: ")
# Out:
# Introduce your sql password: ········

# %%
dbName = "sakila"
connectionData=f"mysql+pymysql://root:{password}@localhost/{dbName}"
engine = alch.create_engine(connectionData)

# %% [markdown]
# ## Saving the Dataset

# %%
rental = pd.read_sql_query(
"""
Select * from rental;
""", engine
)
May_rental.head()
# Out:
#    rental_id         rental_date  inventory_id  customer_id  \
# 0          1 2005-05-24 22:53:30           367          130
# 1          2 2005-05-24 22:54:33          1525          459
# 2          3 2005-05-24 23:03:39          1711          408
# 3          4 2005-05-24 23:04:41          2452          333
# 4          5 2005-05-24 23:05:21          2079          222
#
#           return_date  staff_id         last_update
# 0 2005-05-26 22:04:30         1 2006-02-15 21:30:53
# 1 2005-05-28 19:40:33         1 2006-02-15 21:30:53
# 2 2005-06-01 22:12:39         1 2006-02-15 21:30:53
# 3 2005-06-03 01:43:41         2 2006-02-15 21:30:53
# 4 2005-06-02 04:33:21         1 2006-02-15 21:30:53

# %%
rental
# Out:
#        rental_id          rental_date  inventory_id  customer_id  \
# 0              1  2005-05-24 22:53:30           367          130
# 1              2  2005-05-24 22:54:33          1525          459
# 2              3  2005-05-24 23:03:39          1711          408
# 3              4  2005-05-24 23:04:41          2452          333
# 4              5  2005-05-24 23:05:21          2079          222
# ...          ...                  ...           ...          ...
# 16039      16045  2005-08-23 22:25:26           772           14
# 16040      16046  2005-08-23 22:26:47          4364           74
# 16041      16047  2005-08-23 22:42:48          2088          114
# 16042      16048  2005-08-23 22:43:07          2019          103
# 16043      16049  2005-08-23 22:50:12          2666          393
#
#               return_date  staff_id         last_update
# 0     2005-05-26 22:04:30         1 2006-02-15 21:30:53
# 1     2005-05-28 19:40:33         1 2006-02-15 21:30:53
# ...

# %%
rental["rental_date"]= rental["rental_date"].astype(str)

# %%
rentals_may = rental[rental['rental_date'].str.startswith('2005-05')]
counts_may = rentals_may.groupby("customer_id")["rental_id"].nunique()
final_may = counts_may.reset_index(name='rental_count')
final_may
# Out:
#      customer_id  rental_count
# 0              1             2
# 1              2             1
# 2              3             2
# 3              5             3
# 4              6             3
# ..           ...           ...
# 515          594             4
# 516          595             1
# 517          596             6
# 518          597             2
# 519          599             1
#
# [520 rows x 2 columns]

# %%
rentals_june = rental[rental["rental_date"].apply(lambda x: "-06-" in x)]
counts_june = rentals_june.groupby('customer_id')['rental_id'].nunique()
final_june = counts_june.reset_index(name='rental_count')
final_june
# Out:
#      customer_id  rental_count
# 0              1             7
# 1              2             1
# 2              3             4
# 3              4             6
# 4              5             5
# ..           ...           ...
# 585          595             2
# 586          596             2
# 587          597             3
# 588          598             1
# 589          599             4
#
# [590 rows x 2 columns]

# %%
Merged = pd.merge(final_may,final_june, on = 'customer_id')
Merged
# Out:
#      customer_id  rental_count_x  rental_count_y
# 0              1               2               7
# 1              2               1               1
# 2              3               2               4
# 3              5               3               5
# 4              6               3               4
# ..           ...             ...             ...
# 507          594               4               6
# 508          595               1               2
# 509          596               6               2
# 510          597               2               3
# 511          599               1               4
#
# [512 rows x 3 columns]

# %%
for customer in rental["customer_id"]:
    if rental_may[rental_may["customer_id"] == customer]["customer_id"] > rental_june["customer_id"]
